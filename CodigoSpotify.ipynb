# %%
import requests
import base64
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
# Credenciales de tu app
CLIENT_ID = '6c20194b1f824c5c9209b91693ab04d9'
CLIENT_SECRET = '9c9f450c460040c69d69ab5c13b0447e'

# URL para obtener el token
url = 'https://accounts.spotify.com/api/token'

# Codifica tus credenciales
credentials = f"{'6c20194b1f824c5c9209b91693ab04d9'}:{'9c9f450c460040c69d69ab5c13b0447e'}"
encoded_credentials = base64.b64encode(credentials.encode()).decode()

# Encabezados y datos
headers = {
  'Authorization': f'Basic {encoded_credentials}',
}
data = {
  'grant_type': 'client_credentials',
}

# Solicitar el token
response = requests.post(url, headers=headers, data=data)
if response.status_code == 200:
  token = response.json().get('access_token')
  print(f"Access Token: {token}")
else:
  print(f"Error: {response.status_code}")
  print(response.json())
# Out:
# Access Token: BQBgTS9CjmXpu8ydYXMPg_akVvKMPapmAnzACto0PMgtZpNWuQ3sG-0U_NSRnQwOeYfZcTezyr9Ev2rJYAOuDM8jP9CGdE3UcK-s3Ucr2pf5jWW3LV0

# %%
# Función para buscar y extraer datos de Spotify
def get_spotify_data(sp, genre, year_range):
    results = sp.search(q=f'genre:{genre} year:{year_range}', type='album,track')
    tracks = results['tracks']['items']
    albums = results['albums']['items']

    data = []
    for item in tracks + albums:
        if item['type'] == 'track':
            year = item['album']['release_date'][:4]
        else:
            year = item['release_date'][:4]

        data.append({
            'artist': item['artists'][0]['name'],
            'genre': genre,
            'type': item['type'],
            'name': item['name'],
            'year': year,
            'id': item['id']
        })
    return data

# %%
sp = spotipy.Spotify(auth='BQBgTS9CjmXpu8ydYXMPg_akVvKMPapmAnzACto0PMgtZpNWuQ3sG-0U_NSRnQwOeYfZcTezyr9Ev2rJYAOuDM8jP9CGdE3UcK-s3Ucr2pf5jWW3LV0')

# %%
# Parámetros de búsqueda
start_year = 2020
end_year = 2024
genres = ['rock', 'pop', 'alternative', 'electronic']

# %%
# Obtener los datos
all_data = []
for genre in genres:
    for year in range(start_year, end_year + 1):
        year_range = f"{year}-{year}"
        all_data.extend(get_spotify_data(sp, genre, year_range))

# %%
# Crear un DataFrame de Pandas
df = pd.DataFrame(all_data)

print(df)
# Out:
#                           artist       genre   type  \
# 0                    Arde Bogotá        rock  track
# 1                    Arde Bogotá        rock  track
# 2                   David Bisbal        rock  track
# 3                   David Bisbal        rock  track
# 4                 Jarabe De Palo        rock  track
# ..                           ...         ...    ...
# 219  Happy Birthday to You Music  electronic  album
# 220                Genre-Benders  electronic  album
# 221                Genre-Benders  electronic  album
# 222                Genre Juggler  electronic  album
# 223                    Nivanoise  electronic  album
#
#                                                   name  year  \
# 0                                            Antiaéreo  2020
# 1                                     Virtud y Castigo  2020
# 2                                      A Partir De Hoy  2020
# 3                                     Si Tú La Quieres  2020
# ...

# %%
# Guardar el DataFrame en un archivo CSV
df.to_csv('datos_spotify.csv', index=False)

# %%
df_spo = pd.read_csv("datos_spotify.csv")

# %%
df_spo.head(50)
# Out:
#                   artist genre   type  \
# 0            Arde Bogotá  rock  track
# 1            Arde Bogotá  rock  track
# 2           David Bisbal  rock  track
# 3           David Bisbal  rock  track
# 4         Jarabe De Palo  rock  track
# 5          Glass Animals  rock  track
# 6   Guitarricadelafuente  rock  track
# 7           David Bisbal  rock  track
# 8            Arde Bogotá  rock  track
# 9            Dani Martín  rock  track
# 10             Scenester  rock  album
# 11      Ibiza DJ Rockerz  rock  album
# 12           Arde Bogotá  rock  track
# 13         Oques Grasses  rock  track
# 14               MARLENA  rock  track
# 15           Arde Bogotá  rock  track
# 16               Shinova  rock  track
# 17               Shinova  rock  track
# 18            Elton John  rock  track
# 19            Elton John  rock  track
# 20              Måneskin  rock  track
# 21           Arde Bogotá  rock  track
# 22           Arde Bogotá  rock  track
# ...

# %%
cnx = mysql.connector.connect(user = 'root', password = 'AlumnaAdalab', host = 'localhost', database = 'music_stream_team1')

mycursor = cnx.cursor()

mycursor.execute('SELECT * FROM spotify')

myresult = mycursor.fetchall()
